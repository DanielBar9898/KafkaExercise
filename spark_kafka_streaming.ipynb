# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .config("spark.sql.shuffle.partitions", "2") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-FM2C1AI.bbrouter:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>KafkaSparkStreaming</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.version
# Out:
# '3.5.1'

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .config("spark.sql.shuffle.partitions", "2") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") \
    .getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[1], line 7
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("KafkaSparkStreaming") \
#       5     .config("spark.sql.shuffle.partitions", "2") \
#       6     .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") \
# ----> 7     .getOrCreate()
#       9 spark
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# ...

# %%
kafka_df = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "electric_cars") \
    .load()

# %%
from pyspark.sql.functions import col

cars_stream = kafka_df.selectExpr("CAST(value AS STRING) as json_value")

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .master("local[*]") \
    .config("spark.sql.shuffle.partitions", "2") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") \
    .config("spark.hadoop.fs.file.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .config("spark.hadoop.fs.hdfs.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[1], line 10
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("KafkaSparkStreaming") \
#       5     .master("local[*]") \
#       6     .config("spark.sql.shuffle.partitions", "2") \
#       7     .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") \
#       8     .config("spark.hadoop.fs.file.impl", "org.apache.hadoop.fs.LocalFileSystem") \
#       9     .config("spark.hadoop.fs.hdfs.impl", "org.apache.hadoop.fs.LocalFileSystem") \
# ---> 10     .getOrCreate()
#      12 spark
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# ...

# %%
import os
os.environ["HADOOP_HOME"] = "C:\\hadoop"
os.environ["HADOOP_CONF_DIR"] = "C:\\hadoop\\etc\\hadoop"

# %%
from pyspark.sql import SparkSession
import os

# Create a safe temp directory for Spark
os.makedirs(r"C:\spark-temp", exist_ok=True)

spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .master("local[*]") \
    .config("spark.sql.shuffle.partitions", "2") \
    .config("spark.local.dir", r"C:\spark-temp") \
    .config("spark.hadoop.fs.file.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .config("spark.hadoop.fs.hdfs.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-FM2C1AI.bbrouter:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>KafkaSparkStreaming</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
kafka_df = (
    spark.readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", "localhost:9092")
    .option("subscribe", "electric-cars")   # <-- your topic name
    .option("startingOffsets", "earliest")
    .load()
)

# %%
kafka_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
kafka_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
query = (
    cars_stream.writeStream
    .outputMode("append")
    .format("console")
    .start()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 query = (
# ----> 2     cars_stream.writeStream
#       3     .outputMode("append")
#       4     .format("console")
#       5     .start()
#       6 )
#
# NameError: name 'cars_stream' is not defined

# %%
from pyspark.sql.functions import col

cars_stream = kafka_df.selectExpr("CAST(value AS STRING) as csv_line")

# %%
query = (
    cars_stream.writeStream
    .outputMode("append")
    .format("console")
    .start()
)

# %%
kafka_df = (
    spark.readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", "localhost:9092")
    .option("subscribe", "electric-cars")
    .option("startingOffsets", "earliest")
    .option("failOnDataLoss", "false")
    .option("groupId", "spark-debug")   # <-- IMPORTANT
    .load()
)

# %%
kafka_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
from pyspark.sql.functions import col

cars_stream = kafka_df.selectExpr("CAST(value AS STRING) as csv_line")

# %%
query = (
    cars_stream.writeStream
    .outputMode("append")
    .format("console")
    .trigger(processingTime="5 seconds")
    .start()
)

# %%
query.status
# Out:
# {'message': 'Terminated with exception: org.apache.hadoop.io.nativeio.NativeIO$Windows.access0(Ljava/lang/String;I)Z',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
kafka_df = (
    spark.readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", "localhost:9092")
    .option("subscribe", "electric-cars")
    .option("startingOffsets", "earliest")
    .option("failOnDataLoss", "false")
    .option("groupId", "spark-debug")
    .load()
)

kafka_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
cars_stream = kafka_df.selectExpr("CAST(value AS STRING) as csv_line")

# %%
query = (
    cars_stream.writeStream
    .outputMode("append")
    .format("console")
    .trigger(processingTime="5 seconds")
    .start()
)

# %%
query.status
# Out:
# {'message': 'Terminated with exception: org.apache.hadoop.io.nativeio.NativeIO$Windows.access0(Ljava/lang/String;I)Z',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
from pyspark.sql import SparkSession

# Stop any existing Spark session
try:
    spark = SparkSession.getActiveSession()
    if spark:
        spark.stop()
        print("Stopped existing Spark session.")
    else:
        print("No active Spark session found.")
except Exception as e:
    print("Error stopping Spark session:", e)
# Out:
# Stopped existing Spark session.

# %%
import os

# Safe temp folders for Spark on Windows
os.environ["HADOOP_HOME"] = r"C:\hadoop"
os.environ["HADOOP_TMP_DIR"] = r"C:\hadoop-temp"
os.makedirs(r"C:\hadoop-temp", exist_ok=True)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .master("local[*]") \
    .config("spark.sql.shuffle.partitions", "2") \
    .config("spark.local.dir", r"C:\hadoop-temp") \
    .config("spark.hadoop.fs.file.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .config("spark.hadoop.fs.hdfs.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-FM2C1AI.bbrouter:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>KafkaSparkStreaming</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
kafka_df = (
    spark.readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", "localhost:9092")
    .option("subscribe", "electric-cars")
    .option("startingOffsets", "earliest")
    .option("failOnDataLoss", "false")
    .option("groupId", "spark-debug")
    .load()
)

kafka_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
cars_stream = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "electric-cars") \
    .option("startingOffsets", "earliest") \
    .load()

# Convert Kafka value (bytes) to string
from pyspark.sql.functions import col, from_json
from pyspark.sql.types import StructType, StructField, StringType

schema = StructType([StructField(c, StringType(), True) for c in df.columns])

cars_stream_parsed = cars_stream.select(
    from_json(col("value").cast("string"), schema).alias("data")
).select("data.*")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       9 from pyspark.sql.functions import col, from_json
#      10 from pyspark.sql.types import StructType, StructField, StringType
# ---> 12 schema = StructType([StructField(c, StringType(), True) for c in df.columns])
#      14 cars_stream_parsed = cars_stream.select(
#      15     from_json(col("value").cast("string"), schema).alias("data")
#      16 ).select("data.*")
#
# NameError: name 'df' is not defined
